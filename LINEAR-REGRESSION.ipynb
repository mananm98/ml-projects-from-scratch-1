# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating Data

# %%
x = np.random.randn(100)
x.shape
# Out:
# (100,)

# %%
e = np.random.randn(100)
y = (2*x + 5) + 0.4*e

# %%
plt.scatter(x,y)

# %%
def hypothesis(x,theta):
    return theta[0] + theta[1]*x

# %%
def error(x,y,theta):
    m = x.shape[0]
    e = 0
    for i in range(m):
        hx = hypothesis(x[i],theta)
        e += (hx-y[i])**2
      
    return e

# %%
def gradient(x,y,theta):
    m = x.shape[0]
    grad = np.zeros((2,))
    for i in range(m):
        hx = hypothesis(x[i],theta)
        grad[0] += 2*(hx-y[i])
        grad[1] += 2*(hx - y[i])*x[i]
       
    return grad

# %%
def gradient_descent(x,y,learning_rate=0.0003,iterations=150):
    theta = np.zeros((2,))
    error_list = []
    plt.scatter(x,y)
    for i in range(iterations):
        g = gradient(x,y,theta)
        theta[0] = theta[0] - learning_rate*g[0]
        theta[1] = theta[1] - learning_rate*g[1]
        error_list.append(error(x,y,theta))
        plt.plot(x,(theta[0] + theta[1]*x))
       
    return theta,error_list

# %%
plt.figure(figsize = (10,10))
theta,e_list = gradient_descent(x,y)

# %%
plt.plot(e_list)

# %%
print(theta)
# Out:
# [4.94777243 2.06232752]

# %% [markdown]
# ## The value of theta is :
#  - theta1 : 2.06232752
#  - theta0 : 4.94777243
#  - these values are very close to assumed values 2 and 5
